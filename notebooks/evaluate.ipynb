# %%
# %cd ..
# Out:
# /mnt/disks/disk-2/NLP/aicup

# %%
from xai.scoring import compute_csv

# %%
compute_csv('preds/o/v6/test_sub.csv')
# Out:
#   0%|          | 0/798 [00:00<?, ?it/s]
# 0.7281975642036436
